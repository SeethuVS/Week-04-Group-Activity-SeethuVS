# %%
import pandas as pd
data=pd.read_csv("Telco-Customer-Churn.csv")
data.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %% [markdown]
# # Compare churn count with respect to gender

# %%
sns.countplot(x ='gender', hue='Churn', data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# # Find out how many female senior citizens there in the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Telco-Customer-Churn.csv")
data1=data['gender']=='Female'
data2=data['SeniorCitizen']==1
numbercount=data.loc[data1&data2,:]
sns.countplot(x ='gender', hue='SeniorCitizen', data=numbercount)
plt.legend(loc=(1.02,0))

# %% [markdown]
# # Compare 'tenure' with 'Total Charges'

# %%
import pandas as pd
import seaborn as sns
data=pd.read_csv("Telco-Customer-Churn.csv")
sns.boxplot(x='Churn',y='TotalCharges',data=data)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='TotalCharges'>

# %%
sns.boxplot(x='Churn',y='tenure',data=data)
# Out:
# <AxesSubplot:xlabel='Churn', ylabel='tenure'>

# %%
plt.subplot(1,2,1)
plt.boxplot(data['tenure'])
plt.title('Box plot of Tenure')
plt.xlabel('Tenure')
plt.subplot(1,2,2)
plt.boxplot(data['TotalCharges'])
plt.title('Box plot of TotalCharges')
plt.xlabel('TotalCharges')
plt.style.use('seaborn-whitegrid')

# %%
slicedata=data[['tenure','TotalCharges']]
sns.pairplot(slicedata)

# %% [markdown]
# # Find out which contract is preferred by the senior citizen.

# %%
import seaborn as sns
import pandas as pd
data=pd.read_csv("Telco-Customer-Churn.csv")
data2=data['SeniorCitizen']==1
numbercount=data.loc[data2,:]
sns.countplot(x ='Contract', hue='SeniorCitizen', data=numbercount)
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %% [markdown]
# # Comment on your finds on Payment Method

# %%
import matplotlib.pyplot as plt
sns.countplot(data['PaymentMethod'])
plt.xticks(rotation=90)
# Out:
# C:\Users\SEETHU\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %%
import matplotlib.pyplot as plt
sns.countplot(x ='PaymentMethod', hue='gender', data=data)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %%
import matplotlib.pyplot as plt
sns.countplot(x ='PaymentMethod', hue='InternetService', data=data)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %%
import matplotlib.pyplot as plt
sns.countplot(x ='PaymentMethod', hue='Contract', data=data)
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])
